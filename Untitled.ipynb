# %%
import numpy as  np
import pandas as pd
import yfinance as yf

# %%
df=pd.read_csv("nasdaq_screener_1663891711681.csv")
df
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $124.39
# 1        AA                    Alcoa Corporation Common Stock     $37.52
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.94
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.94
# 4      AACI            Armada Acquisition Corp. I Common Stock   $9.9207
# ...     ...                                                ...       ...
# 8335    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $25.88
# 8336     ZY                         Zymergen Inc. Common Stock     $2.61
# 8337   ZYME                       Zymeworks Inc. Common Shares     $5.33
# 8338   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock   $0.9315
# 8339   ZYXI                            Zynex Inc. Common Stock     $8.78
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# ...
